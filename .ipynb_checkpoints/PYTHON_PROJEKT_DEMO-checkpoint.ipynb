# %% [markdown]
# # Døgnrapporten
#
# I rubrikken nedenfor er det muligt, at ændre start- og slut datoen, for den periode man vil se mængden af hændelser i de forskellige politikredse. Datoen skal angives i formattet yyyy/mm/dd.
#
# Det er også muligt, at angive hvilken type af hændelse man vil have indsigt i. Dette gøres ved at ændre crime til en af nedenstående værdier. Det er dog ikke sikkert, at der er data i alle kategorier, som indeholder lige meget data - vi anbefaler "i alt", da dette henter al dataen.
#
# - i alt
# - uheld
# - vold
# - tyveri
# - brand
# - hærværk
# - euforiserende stoffer
# - andre

# %%
# Applikationen importeres
import application.Eksamen as application

start_date = "2021/05/20" # yyyy/mm/dd
end_date = "2021/05/31" # yyyy/mm/dd

crime = "i alt"

# %%
# Visning af hændelser i søjlediagram
application.chart(start_date, end_date, crime)
# Out:
# Preparing to gather the requested data..
# Starting headless webdriver..
# Gathering daliy police reports.. This may take a while..
# Done gathering police reports.. Found 44 reports
# Reading the reports..
# Comparing incidents..
# Comparing incidents..
# Comparing incidents..
# Comparing incidents..
# Comparing incidents..
# Done reading the reports..
# Creating dataframe..
# Dataframe created.

# %%
# Visning af hændelser på kort
application.map(start_date, end_date, crime)
# Out:
# Preparing to gather the requested data..
# Starting headless webdriver..
# Gathering daliy police reports.. This may take a while..
# Done gathering police reports.. Found 44 reports
# Reading the reports..
# Comparing incidents..
# Comparing incidents..
# Comparing incidents..
# Comparing incidents..
# Comparing incidents..
# Done reading the reports..
# Creating dataframe..
# Dataframe created.
# Figure(layout=FigureLayout(height='420px'))
